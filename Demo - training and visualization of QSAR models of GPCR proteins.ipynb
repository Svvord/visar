# %%
import os
from visar.model_training_utils import (
    ST_model_hyperparam_screen, 
    ST_model_training,
    RobustMT_model_training,
    RobustMT_model_hyperparam_screen
)
from visar.VISAR_model_utils import (
    generate_RUNKEY_dataframe_baseline,
    generate_RUNKEY_dataframe_RobustMT,
    generate_RUNKEY_dataframe_ST,
    generate_performance_plot_ST,
    generate_performance_plot_RobustMT
)

import pandas as pd
import seaborn as sns
from collections import OrderedDict
os.environ['CUDA_VISIBLE_DEVICES']='1'
# Out:
# RDKit WARNING: [10:44:18] Enabling RDKit 2019.09.1 jupyter extensions
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# initialize parameters
protein_targets = ['5HT-1b', '5HT-2b', '5HT-2c']
task_names = ['T106', 'T227', 'T108']
MT_dat_name = './data/MT_data_clean_June28.csv'
FP_type = 'Circular_2048'
log_path = './logs/Demo_GPCRs'
add_features = None
smiles_field = 'salt_removed_smi'
id_field = 'molregno'
dataset_file = './logs/Demo_GPCRs/tmp.csv'
n_features = 2048

# %% [markdown]
# ## Model training and evaluation

# %% [markdown]
# ### baseline model and single-task models

# %%
# set parameters
params_dict = OrderedDict(
    n_tasks = [1],
    
    n_features = [2048], ## need modification given FP types
    activation = ['relu'],
    momentum = [.9],
    batch_size = [128],
    init = ['glorot_uniform'],
    learning_rate = [0.01],
    decay = [1e-6],
    nb_epoch = [30],
    dropouts = [.2, .4],
    nb_layers = [1],
    batchnorm = [False],
    layer_sizes = [(1024, 512),(1024,128) ,(512, 128),(512,64),(128,64),(64,32), 
                   (512,128,64), (128,64,32)],
    penalty = [0.1]
)

# %%
# hyperparam screening using deepchem
log_output = ST_model_hyperparam_screen(MT_dat_name, task_names, FP_type, params_dict, 
                                        log_path = log_path)
# Out:
# ----------------------------------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (3202, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/temp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# Featurizing sample 3000
# TIMING: featurizing shard 0 took 11.672 s
# TIMING: dataset construction took 11.821 s
# Loading dataset from disk.
# Preparing dataset for T51 of rep 1...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.268 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.146 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.148 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.49265437851924554]
# Model 1/16, Metric r2_score, Validation set 0: 0.492654
# 	best_validation_score so far: 0.492654
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.6633628340954005]
# Model 2/16, Metric r2_score, Validation set 1: 0.663363
# 	best_validation_score so far: 0.663363
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.6075783513332119]
# Model 3/16, Metric r2_score, Validation set 2: 0.607578
# 	best_validation_score so far: 0.663363
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6316642176226113]
# Model 4/16, Metric r2_score, Validation set 3: 0.631664
# 	best_validation_score so far: 0.663363
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.626643833710995]
# Model 5/16, Metric r2_score, Validation set 4: 0.626644
# 	best_validation_score so far: 0.663363
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5857365594030519]
# Model 6/16, Metric r2_score, Validation set 5: 0.585737
# 	best_validation_score so far: 0.663363
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.429664146960664]
# Model 7/16, Metric r2_score, Validation set 6: 0.429664
# 	best_validation_score so far: 0.663363
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.5830376419710939]
# Model 8/16, Metric r2_score, Validation set 7: 0.583038
# 	best_validation_score so far: 0.663363
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.5424413427941452]
# Model 9/16, Metric r2_score, Validation set 8: 0.542441
# 	best_validation_score so far: 0.663363
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.6472885129898842]
# Model 10/16, Metric r2_score, Validation set 9: 0.647289
# 	best_validation_score so far: 0.663363
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.640894026955478]
# Model 11/16, Metric r2_score, Validation set 10: 0.640894
# 	best_validation_score so far: 0.663363
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.5771750225954154]
# Model 12/16, Metric r2_score, Validation set 11: 0.577175
# 	best_validation_score so far: 0.663363
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.5941615779172835]
# Model 13/16, Metric r2_score, Validation set 12: 0.594162
# 	best_validation_score so far: 0.663363
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.6332450522689389]
# Model 14/16, Metric r2_score, Validation set 13: 0.633245
# 	best_validation_score so far: 0.663363
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6494148345824753]
# Model 15/16, Metric r2_score, Validation set 14: 0.649415
# 	best_validation_score so far: 0.663363
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.5897143252482084]
# Model 16/16, Metric r2_score, Validation set 15: 0.589714
# 	best_validation_score so far: 0.663363
# computed_metrics: [0.8608094176666592]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.2, 1, False, (1024, 128), 0.1)
# train_score: 0.860809
# validation_score: 0.663363
# Generate performace report ...
# Preparing dataset for T51 of rep 2...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.257 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.141 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.141 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.5366203871363865]
# Model 1/16, Metric r2_score, Validation set 0: 0.536620
# 	best_validation_score so far: 0.536620
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.635799801229309]
# Model 2/16, Metric r2_score, Validation set 1: 0.635800
# 	best_validation_score so far: 0.635800
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.6618626318982359]
# Model 3/16, Metric r2_score, Validation set 2: 0.661863
# 	best_validation_score so far: 0.661863
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6669503600998903]
# Model 4/16, Metric r2_score, Validation set 3: 0.666950
# 	best_validation_score so far: 0.666950
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.5807755913311594]
# Model 5/16, Metric r2_score, Validation set 4: 0.580776
# 	best_validation_score so far: 0.666950
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5938659352961377]
# Model 6/16, Metric r2_score, Validation set 5: 0.593866
# 	best_validation_score so far: 0.666950
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.639698811178733]
# Model 7/16, Metric r2_score, Validation set 6: 0.639699
# 	best_validation_score so far: 0.666950
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.561591286115851]
# Model 8/16, Metric r2_score, Validation set 7: 0.561591
# 	best_validation_score so far: 0.666950
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.6053660548282861]
# Model 9/16, Metric r2_score, Validation set 8: 0.605366
# 	best_validation_score so far: 0.666950
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.6199243357135983]
# Model 10/16, Metric r2_score, Validation set 9: 0.619924
# 	best_validation_score so far: 0.666950
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.645591722052964]
# Model 11/16, Metric r2_score, Validation set 10: 0.645592
# 	best_validation_score so far: 0.666950
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6314764795175839]
# Model 12/16, Metric r2_score, Validation set 11: 0.631476
# 	best_validation_score so far: 0.666950
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.6456998129182263]
# Model 13/16, Metric r2_score, Validation set 12: 0.645700
# 	best_validation_score so far: 0.666950
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.6190223854419833]
# Model 14/16, Metric r2_score, Validation set 13: 0.619022
# 	best_validation_score so far: 0.666950
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6222994628391656]
# Model 15/16, Metric r2_score, Validation set 14: 0.622299
# 	best_validation_score so far: 0.666950
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6380660131433777]
# Model 16/16, Metric r2_score, Validation set 15: 0.638066
# 	best_validation_score so far: 0.666950
# computed_metrics: [0.9234039324589273]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.2, 1, False, (512, 64), 0.1)
# train_score: 0.923404
# validation_score: 0.666950
# Generate performace report ...
# Preparing dataset for T51 of rep 3...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.371 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.155 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.190 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.5504764187623719]
# Model 1/16, Metric r2_score, Validation set 0: 0.550476
# 	best_validation_score so far: 0.550476
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.6279527824450148]
# Model 2/16, Metric r2_score, Validation set 1: 0.627953
# 	best_validation_score so far: 0.627953
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.5615058492113072]
# Model 3/16, Metric r2_score, Validation set 2: 0.561506
# 	best_validation_score so far: 0.627953
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.5180466042070273]
# Model 4/16, Metric r2_score, Validation set 3: 0.518047
# 	best_validation_score so far: 0.627953
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.563677240591177]
# Model 5/16, Metric r2_score, Validation set 4: 0.563677
# 	best_validation_score so far: 0.627953
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5357284751526945]
# Model 6/16, Metric r2_score, Validation set 5: 0.535728
# 	best_validation_score so far: 0.627953
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.5948264821562507]
# Model 7/16, Metric r2_score, Validation set 6: 0.594826
# 	best_validation_score so far: 0.627953
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.5617406262777048]
# Model 8/16, Metric r2_score, Validation set 7: 0.561741
# 	best_validation_score so far: 0.627953
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.5690139096302708]
# Model 9/16, Metric r2_score, Validation set 8: 0.569014
# 	best_validation_score so far: 0.627953
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.6024736936202044]
# Model 10/16, Metric r2_score, Validation set 9: 0.602474
# 	best_validation_score so far: 0.627953
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.5968186882872759]
# Model 11/16, Metric r2_score, Validation set 10: 0.596819
# 	best_validation_score so far: 0.627953
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6324322025278017]
# Model 12/16, Metric r2_score, Validation set 11: 0.632432
# 	best_validation_score so far: 0.632432
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.6101259678769202]
# Model 13/16, Metric r2_score, Validation set 12: 0.610126
# 	best_validation_score so far: 0.632432
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5541291415250552]
# Model 14/16, Metric r2_score, Validation set 13: 0.554129
# 	best_validation_score so far: 0.632432
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6190108855709786]
# Model 15/16, Metric r2_score, Validation set 14: 0.619011
# 	best_validation_score so far: 0.632432
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6068737944108686]
# Model 16/16, Metric r2_score, Validation set 15: 0.606874
# 	best_validation_score so far: 0.632432
# computed_metrics: [0.9141562850372804]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.4, 1, False, (512, 64), 0.1)
# train_score: 0.914156
# validation_score: 0.632432
# Generate performace report ...
# ----------------------------------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (808, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/temp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 3.016 s
# TIMING: dataset construction took 3.081 s
# Loading dataset from disk.
# Preparing dataset for T106 of rep 1...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.087 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.028 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.025 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.20210516011655777]
# Model 1/16, Metric r2_score, Validation set 0: 0.202105
# 	best_validation_score so far: 0.202105
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.7224115604538772]
# Model 2/16, Metric r2_score, Validation set 1: 0.722412
# 	best_validation_score so far: 0.722412
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.7345712390361179]
# Model 3/16, Metric r2_score, Validation set 2: 0.734571
# 	best_validation_score so far: 0.734571
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6981183193265947]
# Model 4/16, Metric r2_score, Validation set 3: 0.698118
# 	best_validation_score so far: 0.734571
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.7025185418024753]
# Model 5/16, Metric r2_score, Validation set 4: 0.702519
# 	best_validation_score so far: 0.734571
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.7214406997789407]
# Model 6/16, Metric r2_score, Validation set 5: 0.721441
# 	best_validation_score so far: 0.734571
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.710824527599543]
# Model 7/16, Metric r2_score, Validation set 6: 0.710825
# 	best_validation_score so far: 0.734571
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6710244672496957]
# Model 8/16, Metric r2_score, Validation set 7: 0.671024
# 	best_validation_score so far: 0.734571
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.288693064155888]
# Model 9/16, Metric r2_score, Validation set 8: 0.288693
# 	best_validation_score so far: 0.734571
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.7067669468052787]
# Model 10/16, Metric r2_score, Validation set 9: 0.706767
# 	best_validation_score so far: 0.734571
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.6795386208197121]
# Model 11/16, Metric r2_score, Validation set 10: 0.679539
# 	best_validation_score so far: 0.734571
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6996625731669679]
# Model 12/16, Metric r2_score, Validation set 11: 0.699663
# 	best_validation_score so far: 0.734571
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.7196518203090576]
# Model 13/16, Metric r2_score, Validation set 12: 0.719652
# 	best_validation_score so far: 0.734571
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5609161026353664]
# Model 14/16, Metric r2_score, Validation set 13: 0.560916
# 	best_validation_score so far: 0.734571
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.7173527454423863]
# Model 15/16, Metric r2_score, Validation set 14: 0.717353
# 	best_validation_score so far: 0.734571
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6155642863056929]
# Model 16/16, Metric r2_score, Validation set 15: 0.615564
# 	best_validation_score so far: 0.734571
# computed_metrics: [0.9052391448600272]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.2, 1, False, (512, 128), 0.1)
# train_score: 0.905239
# validation_score: 0.734571
# Generate performace report ...
# Preparing dataset for T106 of rep 2...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.060 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.027 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.027 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.18087361224022636]
# Model 1/16, Metric r2_score, Validation set 0: 0.180874
# 	best_validation_score so far: 0.180874
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.7152301466118673]
# Model 2/16, Metric r2_score, Validation set 1: 0.715230
# 	best_validation_score so far: 0.715230
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.724276165488216]
# Model 3/16, Metric r2_score, Validation set 2: 0.724276
# 	best_validation_score so far: 0.724276
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6274063259400149]
# Model 4/16, Metric r2_score, Validation set 3: 0.627406
# 	best_validation_score so far: 0.724276
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.6683281172712698]
# Model 5/16, Metric r2_score, Validation set 4: 0.668328
# 	best_validation_score so far: 0.724276
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.6632690553614339]
# Model 6/16, Metric r2_score, Validation set 5: 0.663269
# 	best_validation_score so far: 0.724276
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6737857940359016]
# Model 7/16, Metric r2_score, Validation set 6: 0.673786
# 	best_validation_score so far: 0.724276
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6624339400286258]
# Model 8/16, Metric r2_score, Validation set 7: 0.662434
# 	best_validation_score so far: 0.724276
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.30538564321335504]
# Model 9/16, Metric r2_score, Validation set 8: 0.305386
# 	best_validation_score so far: 0.724276
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.5976096852949582]
# Model 10/16, Metric r2_score, Validation set 9: 0.597610
# 	best_validation_score so far: 0.724276
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.7608567071512521]
# Model 11/16, Metric r2_score, Validation set 10: 0.760857
# 	best_validation_score so far: 0.760857
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.6457970123965262]
# Model 12/16, Metric r2_score, Validation set 11: 0.645797
# 	best_validation_score so far: 0.760857
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.6984556801575443]
# Model 13/16, Metric r2_score, Validation set 12: 0.698456
# 	best_validation_score so far: 0.760857
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.6637723583137329]
# Model 14/16, Metric r2_score, Validation set 13: 0.663772
# 	best_validation_score so far: 0.760857
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.5732927594902538]
# Model 15/16, Metric r2_score, Validation set 14: 0.573293
# 	best_validation_score so far: 0.760857
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6197832629772922]
# Model 16/16, Metric r2_score, Validation set 15: 0.619783
# 	best_validation_score so far: 0.760857
# computed_metrics: [0.9089618558222365]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.4, 1, False, (512, 128), 0.1)
# train_score: 0.908962
# validation_score: 0.760857
# Generate performace report ...
# Preparing dataset for T106 of rep 3...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.087 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.039 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.038 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [-0.02814414713890634]
# Model 1/16, Metric r2_score, Validation set 0: -0.028144
# 	best_validation_score so far: -0.028144
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.6472481412125761]
# Model 2/16, Metric r2_score, Validation set 1: 0.647248
# 	best_validation_score so far: 0.647248
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.5701382177378543]
# Model 3/16, Metric r2_score, Validation set 2: 0.570138
# 	best_validation_score so far: 0.647248
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.675092239780181]
# Model 4/16, Metric r2_score, Validation set 3: 0.675092
# 	best_validation_score so far: 0.675092
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.4656264200546356]
# Model 5/16, Metric r2_score, Validation set 4: 0.465626
# 	best_validation_score so far: 0.675092
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5631191721874202]
# Model 6/16, Metric r2_score, Validation set 5: 0.563119
# 	best_validation_score so far: 0.675092
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6112701957648313]
# Model 7/16, Metric r2_score, Validation set 6: 0.611270
# 	best_validation_score so far: 0.675092
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.5844381057510023]
# Model 8/16, Metric r2_score, Validation set 7: 0.584438
# 	best_validation_score so far: 0.675092
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.3812988938055697]
# Model 9/16, Metric r2_score, Validation set 8: 0.381299
# 	best_validation_score so far: 0.675092
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.5612251329932907]
# Model 10/16, Metric r2_score, Validation set 9: 0.561225
# 	best_validation_score so far: 0.675092
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.5661861454287735]
# Model 11/16, Metric r2_score, Validation set 10: 0.566186
# 	best_validation_score so far: 0.675092
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.637289345630007]
# Model 12/16, Metric r2_score, Validation set 11: 0.637289
# 	best_validation_score so far: 0.675092
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.5800218171421523]
# Model 13/16, Metric r2_score, Validation set 12: 0.580022
# 	best_validation_score so far: 0.675092
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.6112692592507123]
# Model 14/16, Metric r2_score, Validation set 13: 0.611269
# 	best_validation_score so far: 0.675092
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.5779558055429188]
# Model 15/16, Metric r2_score, Validation set 14: 0.577956
# 	best_validation_score so far: 0.675092
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.5112287534957259]
# Model 16/16, Metric r2_score, Validation set 15: 0.511229
# 	best_validation_score so far: 0.675092
# computed_metrics: [0.9377976830949787]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.2, 1, False, (512, 64), 0.1)
# train_score: 0.937798
# validation_score: 0.675092
# Generate performace report ...
# ----------------------------------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (883, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/temp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 3.301 s
# TIMING: dataset construction took 3.362 s
# Loading dataset from disk.
# Preparing dataset for T105 of rep 1...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.075 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.029 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.027 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# ...
# 	best_validation_score so far: 0.612342
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6129168292469087]
# Model 16/16, Metric r2_score, Validation set 15: 0.612917
# 	best_validation_score so far: 0.612917
# computed_metrics: [0.8761833827458141]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.4, 1, False, (128, 64, 32), 0.1)
# train_score: 0.876183
# validation_score: 0.612917
# Generate performace report ...
# Preparing dataset for T10209 of rep 2...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.113 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.049 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.048 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.39884784602783807]
# Model 1/16, Metric r2_score, Validation set 0: 0.398848
# 	best_validation_score so far: 0.398848
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.5718735203434344]
# Model 2/16, Metric r2_score, Validation set 1: 0.571874
# 	best_validation_score so far: 0.571874
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.5675624251476663]
# Model 3/16, Metric r2_score, Validation set 2: 0.567562
# 	best_validation_score so far: 0.571874
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.584892964390028]
# Model 4/16, Metric r2_score, Validation set 3: 0.584893
# 	best_validation_score so far: 0.584893
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.6128246021028053]
# Model 5/16, Metric r2_score, Validation set 4: 0.612825
# 	best_validation_score so far: 0.612825
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.6297007354039863]
# Model 6/16, Metric r2_score, Validation set 5: 0.629701
# 	best_validation_score so far: 0.629701
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6295067490365225]
# Model 7/16, Metric r2_score, Validation set 6: 0.629507
# 	best_validation_score so far: 0.629701
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6019394017221925]
# Model 8/16, Metric r2_score, Validation set 7: 0.601939
# 	best_validation_score so far: 0.629701
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.37091067103055597]
# Model 9/16, Metric r2_score, Validation set 8: 0.370911
# 	best_validation_score so far: 0.629701
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.565883128970974]
# Model 10/16, Metric r2_score, Validation set 9: 0.565883
# 	best_validation_score so far: 0.629701
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.5566041979759467]
# Model 11/16, Metric r2_score, Validation set 10: 0.556604
# 	best_validation_score so far: 0.629701
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.5804763905315324]
# Model 12/16, Metric r2_score, Validation set 11: 0.580476
# 	best_validation_score so far: 0.629701
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.6007795000488692]
# Model 13/16, Metric r2_score, Validation set 12: 0.600780
# 	best_validation_score so far: 0.629701
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5726421259339146]
# Model 14/16, Metric r2_score, Validation set 13: 0.572642
# 	best_validation_score so far: 0.629701
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6123142341750326]
# Model 15/16, Metric r2_score, Validation set 14: 0.612314
# 	best_validation_score so far: 0.629701
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6107587302611639]
# Model 16/16, Metric r2_score, Validation set 15: 0.610759
# 	best_validation_score so far: 0.629701
# computed_metrics: [0.8818240060691044]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.2, 1, False, (64, 32), 0.1)
# train_score: 0.881824
# validation_score: 0.629701
# Generate performace report ...
# Preparing dataset for T10209 of rep 3...
# Computing train/valid/test indices
# TIMING: dataset construction took 0.218 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.076 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.071 s
# Loading dataset from disk.
# Hyperprameter screening ...
# Fitting model 1/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.2664107113779989]
# Model 1/16, Metric r2_score, Validation set 0: 0.266411
# 	best_validation_score so far: 0.266411
# Fitting model 2/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.5799214992887487]
# Model 2/16, Metric r2_score, Validation set 1: 0.579921
# 	best_validation_score so far: 0.579921
# Fitting model 3/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.533973247581708]
# Model 3/16, Metric r2_score, Validation set 2: 0.533973
# 	best_validation_score so far: 0.579921
# Fitting model 4/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.5850845260787016]
# Model 4/16, Metric r2_score, Validation set 3: 0.585085
# 	best_validation_score so far: 0.585085
# Fitting model 5/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.5777371593058599]
# Model 5/16, Metric r2_score, Validation set 4: 0.577737
# 	best_validation_score so far: 0.585085
# Fitting model 6/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.5559097938416122]
# Model 6/16, Metric r2_score, Validation set 5: 0.555910
# 	best_validation_score so far: 0.585085
# Fitting model 7/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.7117134434736652]
# Model 7/16, Metric r2_score, Validation set 6: 0.711713
# 	best_validation_score so far: 0.711713
# Fitting model 8/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.2, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.5966232592736578]
# Model 8/16, Metric r2_score, Validation set 7: 0.596623
# 	best_validation_score so far: 0.711713
# Fitting model 9/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 512), 'penalty': 0.1}
# computed_metrics: [0.3075530647324425]
# Model 9/16, Metric r2_score, Validation set 8: 0.307553
# 	best_validation_score so far: 0.711713
# Fitting model 10/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (1024, 128), 'penalty': 0.1}
# computed_metrics: [0.5363399493318451]
# Model 10/16, Metric r2_score, Validation set 9: 0.536340
# 	best_validation_score so far: 0.711713
# Fitting model 11/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128), 'penalty': 0.1}
# computed_metrics: [0.530889852028021]
# Model 11/16, Metric r2_score, Validation set 10: 0.530890
# 	best_validation_score so far: 0.711713
# Fitting model 12/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 64), 'penalty': 0.1}
# computed_metrics: [0.611602551383952]
# Model 12/16, Metric r2_score, Validation set 11: 0.611603
# 	best_validation_score so far: 0.711713
# Fitting model 13/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64), 'penalty': 0.1}
# computed_metrics: [0.6578947795124187]
# Model 13/16, Metric r2_score, Validation set 12: 0.657895
# 	best_validation_score so far: 0.711713
# Fitting model 14/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (64, 32), 'penalty': 0.1}
# computed_metrics: [0.6055726596200777]
# Model 14/16, Metric r2_score, Validation set 13: 0.605573
# 	best_validation_score so far: 0.711713
# Fitting model 15/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (512, 128, 64), 'penalty': 0.1}
# computed_metrics: [0.6665645974266856]
# Model 15/16, Metric r2_score, Validation set 14: 0.666565
# 	best_validation_score so far: 0.711713
# Fitting model 16/16
# hyperparameters: {'n_tasks': 1, 'n_features': 2048, 'activation': 'relu', 'momentum': 0.9, 'batch_size': 128, 'init': 'glorot_uniform', 'learning_rate': 0.01, 'decay': 1e-06, 'nb_epoch': 30, 'dropouts': 0.4, 'nb_layers': 1, 'batchnorm': False, 'layer_sizes': (128, 64, 32), 'penalty': 0.1}
# computed_metrics: [0.6919618221977921]
# Model 16/16, Metric r2_score, Validation set 15: 0.691962
# 	best_validation_score so far: 0.711713
# computed_metrics: [0.9212477454756548]
# Best hyperparameters: (1, 2048, 'relu', 0.9, 128, 'glorot_uniform', 0.01, 1e-06, 30, 0.2, 1, False, (512, 128, 64), 0.1)
# train_score: 0.921248
# validation_score: 0.711713
# Generate performace report ...

# %%
# option1: hyperparameter automatic selction
hyper_param_df = pd.read_csv(log_path + '/hyperparam_log.txt', header = None, sep = '\t')
hyper_param_df.columns = ['rep_label', 'task_name', 'param', 'r2_score']
hyper_param_df = hyper_param_df.sort_values(by = ['task_name', 'param', 'rep_label'], axis = 0)

best_hyperparams = {}
for task in task_names:
    hyper_stat = hyper_param_df.loc[hyper_param_df['task_name'] == task].groupby('param').agg({'r2_score': ['mean','max','std']})
    valid_mask = hyper_stat['r2_score']['std'] < 0.15 # filter out ones without reasonable generalization power
    hyper_stat = hyper_stat.loc[valid_mask]
    if hyper_stat.shape[0] >= 1:
        select_param = hyper_stat['r2_score']['max'].sort_values(ascending=False).index[0]
        select_r2 = hyper_stat['r2_score']['max'].sort_values(ascending=False)[0]
        
        select_param = select_param.replace('(', '')
        select_param = select_param.replace(')', '')
        
        tmp_layer1 = int(select_param.split(', ')[12])
        tmp_layer2 = int(select_param.split(', ')[13])
        tmp_drop = float(select_param.split(', ')[9])
        
        best_hyperparams[task] = [(tmp_layer1, tmp_layer2, 1), tmp_drop]
        print(task + ': ' + str(hyper_stat.shape[0]) + ', ' + str(select_r2))
    else:
        print(task_name + ' with training variance too high.')
        continue
# Out:
# T51: 16, 0.6669503600998903
# T106: 16, 0.7608567071512521
# T105: 16, 0.8142968318069032
# T10618: 1, 0.4366532947372249
# T107: 16, 0.6875597998996672
# T227: 16, 0.6156729427614069
# T108: 15, 0.6416264896673209
# T168: 12, 0.7567177539543714
# T10624: 13, 0.7958433410936154
# T10627: 16, 0.7017270221559397
# T10209: 16, 0.7117134434736652

# %%
best_hyperparams
# Out:
# {'T51': [(512, 64, 1), 0.2],
#  'T106': [(512, 128, 1), 0.4],
#  'T105': [(512, 128, 1), 0.4],
#  'T10618': [(1024, 128, 1), 0.4],
#  'T107': [(512, 128, 1), 0.2],
#  'T227': [(512, 128, 1), 0.4],
#  'T108': [(1024, 128, 1), 0.4],
#  'T168': [(512, 128, 1), 0.2],
#  'T10624': [(128, 64, 1), 0.4],
#  'T10627': [(1024, 128, 1), 0.4],
#  'T10209': [(512, 128, 1), 0.2]}

# %%
best_hyperparams = {'T106': [(512, 128, 1), 0.4],
                    'T227': [(512, 128, 1), 0.4],
                    'T108': [(1024, 128, 1), 0.4]}

# %%
# model training
output_df = ST_model_training(MT_dat_name, FP_type, 
                              best_hyperparams, result_path = log_path)
# Out:
# ----------------------------------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (3202, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/temp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# Epoch 5/5
# 851/851 [==============================] - 0s 188us/step - loss: 0.0620
# Epoch 1/5
# 851/851 [==============================] - 0s 224us/step - loss: 0.0457
# Epoch 2/5
# 851/851 [==============================] - 0s 223us/step - loss: 0.0477
# Epoch 3/5
# 851/851 [==============================] - 0s 189us/step - loss: 0.0480
# Epoch 4/5
# 851/851 [==============================] - 0s 185us/step - loss: 0.0455
# Epoch 5/5
# 851/851 [==============================] - 0s 197us/step - loss: 0.0466

# %%
# evaluation
plot_df = generate_performance_plot_ST('logs/Demo_GPCRs/performance_metrics.csv')
g = sns.catplot(x = 'task', y = 'value', hue = 'method', 
                col = 'tt', row = 'performance', 
                data = plot_df, kind = 'bar')

# %% [markdown]
# ### Bypass multitask models

# %%
# set parameters
params_dict = OrderedDict(
    n_tasks = [len(task_names)],
    n_features = [2048], ## need modification given FP types
    activation = ['relu'],
    momentum = [.9],
    batch_size = [128],
    init = ['glorot_uniform'],
    learning_rate = [0.0001],
    decay = [1e-6],
    nb_epoch = [30],
    dropouts = [.2, .4],
    nb_layers = [1],
    batchnorm = [False],
    layer_sizes = [(1024, 512),(1024, 128),(512, 128),(512,64)],
    bypass_dropouts = [0.5],
    bypass_layer_sizes = [[128], [64]]
)

# %%
log_output = RobustMT_model_hyperparam_screen(MT_dat_name, task_names, FP_type, params_dict, log_path, smiles_field, id_field)

# %%
# option1: hyperparameter automatic selction
hyper_param_df = pd.read_csv(log_path + '/hyperparam_log.txt', header = None, sep = '\t')
hyper_param_df.columns = ['rep_label', 'param', 'r2_score']
hyper_param_df = hyper_param_df.sort_values(by = ['param', 'rep_label'], axis = 0)

best_hyperparams = {}
hyper_stat = hyper_param_df.groupby('param').agg({'r2_score': ['mean','max','std']})
valid_mask = hyper_stat['r2_score']['std'] < 0.15 # filter out ones without reasonable generalization power
hyper_stat = hyper_stat.loc[valid_mask]
if hyper_stat.shape[0] >= 1:
    select_param = hyper_stat['r2_score']['max'].sort_values(ascending=False).index[0]
    select_r2 = hyper_stat['r2_score']['max'].sort_values(ascending=False)[0]
        
    select_param = select_param.replace('(', '')
    select_param = select_param.replace(')', '')
        
    tmp_layer1 = int(select_param.split(', ')[12])
    tmp_layer2 = int(select_param.split(', ')[13])
    bypass_layer = int(select_param.split(', ')[15].strip('[').strip(']'))
    tmp_drop = float(select_param.split(', ')[9])
        
    best_hyperparams = [(tmp_layer1, tmp_layer2), [bypass_layer], tmp_drop]
    print(str(hyper_stat.shape[0]) + ', ' + str(select_r2))
else:
    print(task_name + ' with training variance too high.')

# %%
best_hyperparams = [(1024, 128), [128], 0.2]

# %%
# train
layer_sizes = best_hyperparams[0]
bypass_layer_sizes = best_hyperparams[1]
dropout = best_hyperparams[2]
lr = 0.0001
bypass_dropouts = 0.5
n_features = 2048

RobustMT_model_training(MT_dat_name, FP_type, task_names, log_path, 
                        n_features, layer_sizes, bypass_layer_sizes, bypass_dropouts, dropout, lr,
                        N_test = 500.0, add_features = None, n_epoch = 250, epoch_num = 10,
                        id_field = id_field, smiles_field = smiles_field)

# %%
# evaluation
plot_df = generate_performance_plot_RobustMT('logs/Demo_GPCRs/model_train_log.csv', 'logs/Demo_GPCRs/model_test_log.csv')
import matplotlib.pyplot as plt
g = sns.FacetGrid(plot_df, col = 'tt', hue = 'tasks')
g = (g.map(plt.plot, 'step', 'R2', marker = '.')).add_legend()

# %% [markdown]
# ## Process trained models for visualization

# %%
# baseline models - RidgeCV
for i in range(len(task_names)):
    task = task_names[i]  # can only be 1 task
    output_prefix = './logs/Demo_GPCRs/RidgeCV_' + task + '_'
    dataset_file = './logs/Demo_GPCRs/tmp.csv'
    
    generate_RUNKEY_dataframe_baseline(output_prefix, task, dataset_file, FP_type, 
                                       add_features = None, mode = 'RidgeCV', 
                                       MT_dat_name = MT_dat_name,
                                       smiles_field = smiles_field, 
                                       id_field = id_field)

# %%
# baseline models - SVR
for i in range(len(task_names)):
    task = task_names[i]  # can only be 1 task
    output_prefix = './logs/Demo_GPCRs/SVR_' + task + '_'
    dataset_file = './logs/Demo_GPCRs/tmp.csv'
    
    generate_RUNKEY_dataframe_baseline(output_prefix, task, dataset_file, FP_type, 
                                       add_features = None, mode = 'SVR', 
                                       MT_dat_name = MT_dat_name,
                                       smiles_field = smiles_field, 
                                       id_field = id_field)

# %%
# single task models
for i in range(len(task_names)):
    task = task_names[i]
    prev_model = 'logs/Demo_GPCRs/' + task + '_rep0_50.hdf5'
    output_prefix = 'logs/Demo_GPCRs/ST_' + task + '_'
    task_list = [task]
    generate_RUNKEY_dataframe_ST(prev_model, output_prefix, task_list, dataset_file, FP_type, 
                                 add_features = None, n_layer = 1)

# %% [markdown]
# ## Analyse compounds of interest by loading a custom file

# %%
# multitask models
custom_file = './data/custom_file.txt'
custom_id_field = 'id'
custom_task_field = 'dummy_value'
custom_smiles_field = 'SMILES'
sep_custom_file = '\t'
output_prefix = './logs/Demo_GPCRs/RobustMT2_'

prev_model = './logs/Demo_GPCRs/model-2250'
layer_sizes = [1024, 128]
bypass_layer_sizes = [128]
dropout = 0.2
n_layer = 1
n_bypass = 2
model_flag = 'MT'

generate_RUNKEY_dataframe_RobustMT(prev_model, output_prefix, task_names, dataset_file, FP_type, add_features, 
                              n_features, layer_sizes, bypass_layer_sizes, model_flag, n_bypass,
                              MT_dat_name, model_test_log = './logs/Demo_GPCRs/model_test_log.csv',
                              smiles_field = smiles_field, id_field = id_field,
                              bypass_dropouts = [.5], dropout = dropout, learning_rate = 0.001, n_layer = n_layer,
                              custom_file = custom_file, custom_id_field = custom_id_field, 
                              custom_task_field = custom_task_field, custom_smiles_field = custom_smiles_field,
                              sep_custom_file = sep_custom_file, K = 5, valid_cutoff = None)
# Out:
# ------------- Loading dataset --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (2939, 5)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# TIMING: featurizing shard 0 took 10.879 s
# TIMING: dataset construction took 11.040 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.018 s
# Loading dataset from disk.
# ------------- Loading previous trained models ------------------
# INFO:tensorflow:Restoring parameters from ./logs/Demo_GPCRs/model-2250
# ------------- Prepare information for chemicals ------------------
# INFO:tensorflow:Restoring parameters from ./logs/Demo_GPCRs/model-2250
# ------------- Prepare information for minibatches ------------------
# ------------- Prepare information for tasks ------------------
# INFO:tensorflow:Restoring parameters from ./logs/Demo_GPCRs/model-2250
# INFO:tensorflow:Restoring parameters from ./logs/Demo_GPCRs/model-2250
# INFO:tensorflow:Restoring parameters from ./logs/Demo_GPCRs/model-2250
# ------- Generate color labels with default K of 3 --------
# -------------- Saving datasets ----------------

# %%
# baseline models -- RidgeCV
custom_file = './data/custom_file.txt'
custom_id_field = 'id'
custom_task_field = 'dummy_value'
custom_smiles_field = 'SMILES'
sep_custom_file = '\t'
model_flag = 'MT'

for i in range(len(task_names)):
    task = task_names[i]
    output_prefix = './logs/Demo_GPCRs/RidgeCV_' + task + '_new_'
    
    generate_RUNKEY_dataframe_baseline(output_prefix, task, dataset_file, FP_type, 
                                   add_features, mode = 'RidgeCV', 
                                   MT_dat_name = MT_dat_name, 
                                   smiles_field = smiles_field, id_field = id_field,
                                   custom_file = custom_file, custom_id_field = custom_id_field, 
                                   custom_task_field = custom_task_field, 
                                   custom_smiles_field = custom_smiles_field,
                                   sep_custom_file = sep_custom_file)

# %%
# baseline models -- SVR
custom_file = './data/custom_file.txt'
custom_id_field = 'id'
custom_task_field = 'dummy_value'
custom_smiles_field = 'SMILES'
sep_custom_file = '\t'
model_flag = 'MT'

for i in range(len(task_names)):
    task = task_names[i]
    output_prefix = './logs/Demo_GPCRs/SVR_' + task + '_new_'
    
    generate_RUNKEY_dataframe_baseline(output_prefix, task, dataset_file, FP_type, 
                                   add_features, mode = 'SVR', 
                                   MT_dat_name = MT_dat_name, 
                                   smiles_field = smiles_field, id_field = id_field,
                                   custom_file = custom_file, custom_id_field = custom_id_field, 
                                   custom_task_field = custom_task_field, 
                                   custom_smiles_field = custom_smiles_field,
                                   sep_custom_file = sep_custom_file)

# %%
# single task models
custom_file = './data/custom_file.txt'
custom_id_field = 'id'
custom_task_field = 'dummy_value'
custom_smiles_field = 'SMILES'
sep_custom_file = '\t'
model_flag = 'MT'

for i in range(len(task_names)):
    task = task_names[i]
    output_prefix = './logs/Demo_GPCRs/ST_' + task + '_new_'
    prev_model = './logs/Demo_GPCRs/' + task + '_rep0_50.hdf5'
    
    generate_RUNKEY_dataframe_ST(prev_model, output_prefix, [task], dataset_file, FP_type, 
                             add_features, mode = 'ST',
                             MT_dat_name = MT_dat_name, n_layer = 1,
                             smiles_field = smiles_field, id_field = id_field,
                             custom_file = custom_file, custom_id_field = custom_id_field, 
                             custom_task_field = custom_task_field, 
                             custom_smiles_field = custom_smiles_field,
                             sep_custom_file = sep_custom_file)

# %% [markdown]
# ## supplementary: all SVR prediction and SAR plots

# %%
# initialize parameters
task_names = ['T51', 'T106', 'T105', 'T10618', 
              'T107', 'T227', 'T108',
              'T168', 'T10624', 'T10627', 'T10209']
MT_dat_name = './data/MT_data_clean_June28.csv'
FP_type = 'Circular_2048'
log_path = './logs/Demo_GPCRs'
add_features = None
smiles_field = 'salt_removed_smi'
id_field = 'molregno'
dataset_file = './logs/Demo_GPCRs/tmp.csv'
n_features = 2048

# %%
# baseline models -- SVR
custom_file = './data/custom_file.txt'
custom_id_field = 'id'
custom_task_field = 'dummy_value'
custom_smiles_field = 'SMILES'
sep_custom_file = '\t'
model_flag = 'MT'

for i in range(len(task_names)):
    task = task_names[i]
    output_prefix = './logs/Demo_GPCRs/SVR_' + task + '_new_'
    
    generate_RUNKEY_dataframe_baseline(output_prefix, task, dataset_file, FP_type, 
                                   add_features, mode = 'SVR', 
                                   MT_dat_name = MT_dat_name, 
                                   smiles_field = smiles_field, id_field = id_field,
                                   custom_file = custom_file, custom_id_field = custom_id_field, 
                                   custom_task_field = custom_task_field, 
                                   custom_smiles_field = custom_smiles_field,
                                   sep_custom_file = sep_custom_file)
# Out:
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (3202, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# Featurizing sample 3000
# TIMING: featurizing shard 0 took 11.793 s
# TIMING: dataset construction took 11.952 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.213 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.097 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.093 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (808, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 3.710 s
# TIMING: dataset construction took 3.763 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.013 s
# TIMING: dataset construction took 0.020 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.058 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.030 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.028 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (883, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 3.574 s
# TIMING: dataset construction took 3.627 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.013 s
# TIMING: dataset construction took 0.021 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.068 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.034 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.032 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (109, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.396 s
# TIMING: dataset construction took 0.408 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.012 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.007 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.007 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (2951, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# TIMING: featurizing shard 0 took 12.300 s
# TIMING: dataset construction took 12.469 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.020 s
# TIMING: dataset construction took 0.030 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.364 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.168 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.128 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (1064, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 3.989 s
# TIMING: dataset construction took 4.046 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.029 s
# TIMING: dataset construction took 0.045 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.115 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.051 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.050 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (2063, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# TIMING: featurizing shard 0 took 8.156 s
# TIMING: dataset construction took 8.255 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.134 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.063 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.062 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (396, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 1.598 s
# TIMING: dataset construction took 1.624 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.030 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.016 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.016 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (313, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 1.186 s
# TIMING: dataset construction took 1.210 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.014 s
# TIMING: dataset construction took 0.022 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.029 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.014 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.014 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (2523, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# TIMING: featurizing shard 0 took 10.935 s
# TIMING: dataset construction took 11.073 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.013 s
# TIMING: dataset construction took 0.021 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.220 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.107 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.111 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (1560, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 6.312 s
# TIMING: dataset construction took 6.394 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.114 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.049 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.047 s
# Loading dataset from disk.
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------

# %%
# baseline models -- RidgeCV
custom_file = './data/custom_file.txt'
custom_id_field = 'id'
custom_task_field = 'dummy_value'
custom_smiles_field = 'SMILES'
sep_custom_file = '\t'
model_flag = 'MT'

for i in range(len(task_names)):
    task = task_names[i]
    output_prefix = './logs/Demo_GPCRs/RidgeCV_' + task + '_new_'
    
    generate_RUNKEY_dataframe_baseline(output_prefix, task, dataset_file, FP_type, 
                                   add_features, mode = 'RidgeCV', 
                                   MT_dat_name = MT_dat_name, 
                                   smiles_field = smiles_field, id_field = id_field,
                                   custom_file = custom_file, custom_id_field = custom_id_field, 
                                   custom_task_field = custom_task_field, 
                                   custom_smiles_field = custom_smiles_field,
                                   sep_custom_file = sep_custom_file)
# Out:
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (3202, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# Featurizing sample 3000
# TIMING: featurizing shard 0 took 11.767 s
# TIMING: dataset construction took 11.925 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.272 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.151 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.151 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (808, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 3.005 s
# TIMING: dataset construction took 3.048 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.055 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.029 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.027 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (883, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 3.538 s
# TIMING: dataset construction took 3.587 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.063 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.031 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.029 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (109, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.596 s
# TIMING: dataset construction took 0.612 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.018 s
# TIMING: dataset construction took 0.028 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.016 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.010 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.011 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (2951, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# TIMING: featurizing shard 0 took 11.033 s
# TIMING: dataset construction took 11.175 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.026 s
# TIMING: dataset construction took 0.038 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.329 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.170 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.137 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (1064, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 4.101 s
# TIMING: dataset construction took 4.158 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.031 s
# TIMING: dataset construction took 0.046 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.113 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.052 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.051 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (2063, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# TIMING: featurizing shard 0 took 7.791 s
# TIMING: dataset construction took 7.892 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.159 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.084 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.081 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (396, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 1.662 s
# TIMING: dataset construction took 1.699 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.018 s
# TIMING: dataset construction took 0.028 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.041 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.016 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.015 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (313, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 1.135 s
# TIMING: dataset construction took 1.156 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.024 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.013 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.012 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (2523, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# Featurizing sample 2000
# TIMING: featurizing shard 0 took 9.287 s
# TIMING: dataset construction took 9.406 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.020 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.160 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.078 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.077 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
# ------------- Loading dataset and train baseline model --------------------
# /home/dqy14/miniconda3/envs/deepchem_visar/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (767) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Extracted dataset shape: (1560, 3)
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 5.703 s
# TIMING: dataset construction took 5.779 s
# Loading dataset from disk.
# ------------- Loading custom file --------------------
# 0
# Read in 3 compounds; 3 valid compounds.
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ./logs/Demo_GPCRs/tmp.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.012 s
# TIMING: dataset construction took 0.019 s
# Loading dataset from disk.
# Computing train/valid/test indices
# TIMING: dataset construction took 0.101 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.050 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.048 s
# Loading dataset from disk.
# ------------- Prepare information for chemicals ------------------
# ------------- Prepare information for minibatches ------------------
# ------------- Saving datasets --------------
